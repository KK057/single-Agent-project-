# %%
#''''''GROQ''''''''''
import os
import openai
from dotenv import load_dotenv

load_dotenv()

client = openai.OpenAI(
    api_key=os.environ.get("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
)

models = client.models.list()
for model in models.data:
    print(model.id)
# Out:
# whisper-large-v3
# qwen/qwen3.8-27b
# meta-llama/llama-prompt-guard-2-86m
# openai/gpt-oss-20b
# canopylabs/orpheus-v1-english
# openai/gpt-oss-safeguard-20b
# openai/gpt-oss-120b
# allam-2-7b
# canopylabs/orpheus-arabic-saudi
# whisper-large-v3-turbo
# meta-llama/llama-prompt-guard-2-22m

# %%
import os
import openai
from dotenv import load_dotenv

# Load environment variables from .env
load_dotenv()

# Initialize client pointing to Groq's API
client = openai.OpenAI(
    api_key=os.environ.get("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
)

# Fetch the list of available models
models = client.models.list()

# Print each model ID
print("Available Groq Models:")
for model in models.data:
    print(f"- {model.id}")
# Out:
# Available Groq Models:
# - whisper-large-v3
# - whisper-large-v3-turbo
# - openai/gpt-oss-safeguard-20b
# - qwen/qwen3.8-27b
# - openai/gpt-oss-120b
# - canopylabs/orpheus-v1-english
# - allam-2-7b
# - meta-llama/llama-prompt-guard-2-86m
# - canopylabs/orpheus-arabic-saudi
# - meta-llama/llama-prompt-guard-2-22m
# - openai/gpt-oss-20b

# %%
completion = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "user", "content": "hello, how are you?"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# Hello! I'm doing great, thanks for asking. How can I help you today?

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

model = init_chat_model("google_genai:gemini-3.5-flash-lite")
response = model.invoke("Why should I use LangChain?")
response.content
# Out:
# [{'type': 'text',
#   'text': 'You should use **LangChain** if you are building complex, data-aware, or agentic applications powered by Large Language Models (LLMs) like GPT-4, Claude, or open-source models, and you find that making raw API calls is becoming too limiting or messy.\n\nHere is a breakdown of the specific reasons to use LangChain, along with a few reasons why you *might not* need it.\n\n---\n\n### Key Reasons to Use LangChain\n\n#### 1. It Solves the "Glue Code" Problem\nMaking a simple API call to OpenAI is easy. But building a real application requires chaining multiple steps: taking user input, querying a vector database, injecting context into a prompt, calling the LLM, parsing the output, and managing conversation history. LangChain provides standardized components ("chains") to wire these pieces together quickly.\n\n#### 2. Excellent Integration Ecosystem\nLangChain has hundreds of out-of-the-box integrations with:\n*   **LLMs & Embedding Providers:** OpenAI, Anthropic, Hugging Face, Cohere, Local models (Llamafile, Ollama), etc.\n*   **Vector Databases:** Pinecone, Chroma, Weaviate, FAISS, Milvus, etc.\n*   **Data Sources & Document Loaders:** PDFs, Notion, Slack, SQL databases, GitHub, websites, and more.\n*   If you had to write custom API integrations for all of these, you’d spend weeks before even starting your core product.\n\n#### 3. Easy Retrieval-Augmented Generation (RAG)\nIf you want to chat with your own data (e.g., "Ask questions about my company\'s HR manual"), LangChain provides high-level abstractions to:\n*   Split large documents into chunks.\n*   Convert them into embeddings and store them in a vector DB.\n*   Retrieve the most relevant chunks based on a user\'s question and feed them to the LLM.\n\n#### 4. Advanced Agents and Tools\nLLMs are great at reasoning, but bad at execution. LangChain makes it easy to build **Agents**—systems where the LLM decides *which* tools to use (e.g., a calculator, a web search API, or a SQL database query) to answer a complex multi-step question.\n\n#### 5. Memory Management\nLLMs are stateless; they don\'t remember past messages. LangChain provides built-in memory modules that automatically manage conversation history, summarizing old messages or keeping a rolling window so you don\'t blow past token limits.\n\n#### 6. LangGraph (for Complex Workflows)\nLangChain’s ecosystem now includes **LangGraph**, a powerful library for building stateful, multi-actor applications (like coding assistants or complex research agents) with cyclical logic—something traditional linear chains struggle to do.\n\n---\n\n### When Should You NOT Use LangChain?\n\nTo be fair, LangChain isn\'t always the right choice. You might want to skip it if:\n1.  **Your app is extremely simple:** If you are just sending a single prompt and getting a single text response, LangChain is overkill. Use the native `openai` or `anthropic` Python SDKs.\n2.  **You want maximum control and transparency:** LangChain can act as a "black box" with a lot of abstraction magic happening under the hood. When something breaks, debugging through multiple layers of abstraction can be frustrating.\n3.  **You hate churn:** LangChain evolves very fast, which historically meant breaking changes (though the API has stabilized significantly recently).\n\n---\n\n### Summary\nUse **LangChain** if you want to **prototype fast**, need to **connect your LLM to external data and tools (RAG & Agents)**, and don\'t want to spend time writing custom boilerplate code for API integrations, memory, and prompt management.',
#   'extras': {'signature': 'El4KXAFpFH0Taehr+ZH0rrTNBRm4ks2F+z0Y8hlvXlPd1YnFxVVY3oDRHJ5vesHNS8V+SHEFBgQQa2eQB2K/Axs7Kz64nmUMHqfQkKVigy0i0lnQ46GM9jZHBWjqvKZR'}}]
